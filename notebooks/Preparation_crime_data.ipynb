# %% [markdown]
# <a href="https://colab.research.google.com/github/Many98/real_estate/blob/criminality/notebooks/Preparation_crime_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import xarray as xr
import datetime 

from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
pd.set_option('display.max_columns', None)
df = pd.read_csv('/content/drive/MyDrive/reality/criminality.csv', sep=',', delimiter=None, encoding="utf8")
df_nopred = pd.read_csv('/content/drive/MyDrive/reality/dataset_2.csv', sep=',', delimiter=None, encoding="utf8")

# %%
df.head()
# Out:
#      id          x          y                            date  \
# 0  9459  14.506315  50.078251  2012-11-01T12:15:00.0000+01:00
# 1  9504  14.352074  50.074896  2012-01-04T12:24:00.0000+01:00
# 2  9504  14.352074  50.074896  2012-01-04T12:24:00.0000+01:00
# 3  9516  14.424811  50.076587  2012-05-18T20:00:00.0000+02:00
# 4  9554  14.399052  50.033251  2012-10-26T14:57:00.0000+02:00
#
#                                          types
# 0                        krádeže součástek aut
# 1                   vloupání do rodinných domů
# 2  krádeže motorových vozidel (jednostopových)
# 3                        krádeže součástek aut
# 4                   vloupání do rodinných domů

# %%
df_nopred.columns
# Out:
# Index(['city_district', 'additional_disposition', 'air_quality', 'atm_dist',
#        'built_density', 'bus_station_dist', 'construction_type', 'daily_noise',
#        'date', 'desc_hash', 'description', 'disposition', 'doctor_dist',
#        'electricity', 'electricity_txt', 'energy_effeciency', 'equipment',
#        'floor', 'floor_area', 'gas', 'geometry', 'gp_ci_high_price',
#        'gp_ci_low_price', 'gp_mean_price', 'gp_std_price', 'has_balcony',
#        'has_cellar', 'has_garage', 'has_garden', 'has_lift', 'has_loggia',
#        'has_parking', 'hash', 'header', 'heating', 'heating_txt',
#        'kindergarten_dist', 'lat', 'long', 'name', 'nightly_noise',
#        'no_barriers', 'note', 'ownership', 'pharmacy_dist', 'place',
#        'playground_dist', 'post_office_dist', 'price', 'primary_school_dist',
#        'restaurant_pub_dist', 'sports_field_dist', 'state',
#        'subway_station_dist', 'sun_glare', 'supermarket_grocery_dist', 'tags',
#        'telecomunication', 'telecomunication_txt', 'theatre_cinema_dist',
#        'train_station_dist', 'tram_station_dist', 'transport', 'usable_area',
#        'vet_dist', 'waste', 'waste_txt', 'year_reconstruction', 'park_dist'],
#       dtype='object')

# %%
df2 = df_nopred[df_nopred.columns.difference(['city_district', 'additional_disposition', 'air_quality', 'atm_dist',
       'built_density', 'bus_station_dist', 'construction_type', 'daily_noise',
       'date', 'desc_hash', 'description', 'disposition', 'doctor_dist',
       'electricity', 'electricity_txt', 'energy_effeciency', 'equipment',
       'floor', 'floor_area', 'gas', 'geometry', 'gp_ci_high_price',
       'gp_ci_low_price', 'gp_mean_price', 'gp_std_price', 'has_balcony',
       'has_cellar', 'has_garage', 'has_garden', 'has_lift', 'has_loggia',
       'has_parking', 'hash', 'header', 'heating', 'heating_txt',
       'kindergarten_dist', 'name', 'nightly_noise',
       'no_barriers', 'note', 'ownership', 'pharmacy_dist', 'place',
       'playground_dist', 'post_office_dist', 'price', 'primary_school_dist',
       'restaurant_pub_dist', 'sports_field_dist', 'state',
       'subway_station_dist', 'sun_glare', 'supermarket_grocery_dist', 'tags',
       'telecomunication', 'telecomunication_txt', 'theatre_cinema_dist',
       'train_station_dist', 'tram_station_dist', 'transport', 'usable_area',
       'vet_dist', 'waste', 'waste_txt', 'year_reconstruction', 'park_dist'])]

# %%
df.describe(include='all')
# Out:
#                   id              x              y  \
# count   1.420260e+05  142026.000000  142026.000000
# unique           NaN            NaN            NaN
# top              NaN            NaN            NaN
# freq             NaN            NaN            NaN
# mean    1.149821e+07      14.447862      50.074537
# std     3.606041e+06       0.058023       0.031131
# min     9.459000e+03      14.252392      49.945697
# 25%     8.618142e+06      14.419374      50.056977
# 50%     1.124758e+07      14.439100      50.077606
# 75%     1.393246e+07      14.480979      50.091109
# max     1.970392e+07      14.696000      50.171682
#
#                                   date               types
# count                           142026              142026
# unique                          130296                  27
# top     2020-07-09T15:41:00.0000+02:00  krádeže na osobách
# freq                                13               47110
# mean                               NaN                 NaN
# std                                NaN                 NaN
# min                                NaN                 NaN
# 25%                                NaN                 NaN
# 50%                                NaN                 NaN
# 75%                                NaN                 NaN
# max                                NaN                 NaN

# %%
df.dtypes
# Out:
# id         int64
# x        float64
# y        float64
# date      object
# types     object
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'], utc = True)

# %%
df.head()
# Out:
#      id          x          y                      date  \
# 0  9459  14.506315  50.078251 2012-11-01 11:15:00+00:00
# 1  9504  14.352074  50.074896 2012-01-04 11:24:00+00:00
# 2  9504  14.352074  50.074896 2012-01-04 11:24:00+00:00
# 3  9516  14.424811  50.076587 2012-05-18 18:00:00+00:00
# 4  9554  14.399052  50.033251 2012-10-26 12:57:00+00:00
#
#                                          types
# 0                        krádeže součástek aut
# 1                   vloupání do rodinných domů
# 2  krádeže motorových vozidel (jednostopových)
# 3                        krádeže součástek aut
# 4                   vloupání do rodinných domů

# %%
df['date'] = pd.to_datetime(df['date']).dt.date
df.head()
# Out:
#      id          x          y        date  \
# 0  9459  14.506315  50.078251  2012-11-01
# 1  9504  14.352074  50.074896  2012-01-04
# 2  9504  14.352074  50.074896  2012-01-04
# 3  9516  14.424811  50.076587  2012-05-18
# 4  9554  14.399052  50.033251  2012-10-26
#
#                                          types
# 0                        krádeže součástek aut
# 1                   vloupání do rodinných domů
# 2  krádeže motorových vozidel (jednostopových)
# 3                        krádeže součástek aut
# 4                   vloupání do rodinných domů

# %%
df2 = df[df['date']>datetime.date(2016, 1, 1)]

# %%
df2.head()
# Out:
#          id          x          y        date                  types
# 85  6027950  14.423841  50.089270  2016-01-02     krádeže na osobách
# 86  6027956  14.448420  50.082480  2016-01-02  krádeže součástek aut
# 87  6027958  14.418877  50.077282  2016-01-02   vloupání do prodejny
# 88  6027982  14.427781  50.078349  2016-01-02     krádeže na osobách
# 89  6028004  14.421398  50.084477  2016-01-02     krádeže na osobách

# %%
df2.describe()
# Out:
#                  id              x              y
# count  1.394080e+05  139408.000000  139408.000000
# mean   1.161785e+07      14.447896      50.074527
# std    3.526139e+06       0.057831       0.031090
# min    6.027950e+06      14.252392      49.945697
# 25%    8.757992e+06      14.419406      50.056977
# 50%    1.134748e+07      14.439100      50.077702
# 75%    1.398396e+07      14.480979      50.091089
# max    1.970392e+07      14.696000      50.171682

# %% [markdown]
# ## Done cut of time

# %%
print(df.types.unique())
# Out:
# ['krádeže součástek aut' 'vloupání do rodinných domů'
#  'krádeže motorových vozidel (jednostopových)' 'vloupání do bytu'
#  'krádeže motorových vozidel (dvoustopových)' 'nebezpečné vyhrožování'
#  'krádeže jízdních kol' 'nedovolené ozbrojování' 'krádeže na osobách'
#  'loupež' 'úmyslné ublížení na zdraví' 'vloupání do prodejny'
#  'vloupání do ubytovacích objektů' 'vloupání do restaurace'
#  'dopravní nehody' 'obecné ohrožení' 'vražda' 'omezování osobní svobody'
#  'výtržnictví' 'útok proti výkonu pravomoci stát. orgánu' 'vydírání'
#  'rvačka' 'chladná zbraň' 'střelná zbraň'
#  'násilí proti skupině/jednotlivci' 'obchod s lidmi' 'únos']

# %%
df['crime_idx'] = 0

# %%
crime_lists = [['obecné ohrožení', 'dopravní nehody'],
               ['omezování osobní svobody', 'krádeže součástek aut',
                'krádeže motorových vozidel (jednostopových)', 
                'nebezpečné vyhrožování', 'krádeže jízdních kol', 
                'nedovolené ozbrojování', 'vloupání do restaurace',
                'vydírání', 'rvačka'],
               ['vloupání do rodinných domů', 'vloupání do bytu',
                'krádeže motorových vozidel (dvoustopových)', 'krádeže na osobách',
                'loupež', 'úmyslné ublížení na zdraví', 'vloupání do prodejny',
                'vloupání do ubytovacích objektů', 'výtržnictví', 
                'útok proti výkonu pravomoci stát. orgánu','chladná zbraň', 
                'střelná zbraň', 'násilí proti skupině/jednotlivci'],
               ['vražda', 'obchod s lidmi', 'únos']]

# %%
0.02 + 0.2 + 0.28 + 0.5
# Out:
# 1.0

# %%
crime_weight = [0.02, 0.28, 0.5, 0.2]

# %%
df2 = df2.reset_index()
for x in range(len(df2['types'])):
  for i in range(len(crime_lists)):
    if df2.loc[x,'types'] in crime_lists[i]:
      df2.loc[x,'crime_idx'] = crime_weight[i]/len(crime_lists[i])

# %%
df2.head()
# Out:
#    index       id          x          y        date                  types  \
# 0     85  6027950  14.423841  50.089270  2016-01-02     krádeže na osobách
# 1     86  6027956  14.448420  50.082480  2016-01-02  krádeže součástek aut
# 2     87  6027958  14.418877  50.077282  2016-01-02   vloupání do prodejny
# 3     88  6027982  14.427781  50.078349  2016-01-02     krádeže na osobách
# 4     89  6028004  14.421398  50.084477  2016-01-02     krádeže na osobách
#
#    crime_idx
# 0   0.038462
# 1   0.031111
# 2   0.038462
# 3   0.038462
# 4   0.038462

# %%
df2.describe()
# Out:
#                index            id              x              y  \
# count  139408.000000  1.394080e+05  139408.000000  139408.000000
# mean    10459.651770  1.161785e+07      14.447896      50.074527
# std      6483.013071  3.526139e+06       0.057831       0.031090
# min         0.000000  6.027950e+06      14.252392      49.945697
# 25%      4991.000000  8.757992e+06      14.419406      50.056977
# 50%      9969.500000  1.134748e+07      14.439100      50.077702
# 75%     15308.000000  1.398396e+07      14.480979      50.091089
# max     25027.000000  1.970392e+07      14.696000      50.171682
#
#            crime_idx
# count  139408.000000
# mean        0.034807
# std         0.005536
# min         0.010000
# 25%         0.031111
# 50%         0.038462
# 75%         0.038462
# max         0.066667

# %%
df2['cut_x'] = pd.cut(df2['x'], 250)

# %%
df2['cut_y'] = pd.cut(df2['y'], 250)

# %% [markdown]
# Maximalni datum je datetime.date(2022, 10, 27)

# %%
max(df2['date'])
# Out:
# datetime.date(2022, 10, 27)

# %%
from dateutil.relativedelta import relativedelta

# %%
relativedelta(max(df2['date']), min(df2['date']))
# Out:
# relativedelta(years=+6, months=+9, days=+25)

# %%
difference_in_years = relativedelta(max(df2['date']), min(df2['date'])).years
difference_in_years
# Out:
# 6

# %%
df2.loc[0, 'date']
# Out:
# datetime.date(2016, 1, 2)

# %%
def discount_crimes(discount, df):
  df['disc_index'] = 0
  df['disc_index'] = [discount**(relativedelta(max(df['date']), df.loc[x,'date']).years)*x 
                      for x in df['index']]
  return df

# %%
discount_factor = 0.9
df2['disc_index'] = 0
N = len(df2['crime_idx'])
for i in range(N):
  df2.loc[i, 'disc_index'] = discount_factor**(relativedelta(max(df2['date']), df2.loc[i,'date']).years)*df2.loc[i,'crime_idx']

# %% [markdown]
# 5000 trvalo cca 64sec
#
# 1000 12sec
#
# FULL 23min 17sec

# %%
df2.tail()
# Out:
#         index        id          x          y        date  \
# 139403  12788  19656779  14.315833  50.069531  2022-10-26
# 139404  12789  19656917  14.472246  50.069943  2022-10-26
# 139405  12790  19657135  14.494546  50.100211  2022-10-26
# 139406  12791  19657389  14.437646  50.047865  2022-10-26
# 139407  12792  19657842  14.432017  50.053607  2022-10-27
#
#                                              types  crime_idx  \
# 139403                       krádeže součástek aut   0.031111
# 139404  krádeže motorových vozidel (dvoustopových)   0.038462
# 139405                             dopravní nehody   0.010000
# 139406                       krádeže součástek aut   0.031111
# 139407                       krádeže součástek aut   0.031111
#
#                    cut_x               cut_y  disc_index
# 139403  (14.314, 14.316]  (50.0686, 50.0695]    0.031111
# 139404  (14.471, 14.472]  (50.0695, 50.0704]    0.038462
# 139405  (14.494, 14.495]  (50.0994, 50.1003]    0.010000
# 139406  (14.437, 14.439]  (50.0478, 50.0487]    0.031111
# 139407  (14.432, 14.433]  (50.0533, 50.0542]    0.031111

# %%
df2.to_csv('discounted_crime.csv', index=True)
